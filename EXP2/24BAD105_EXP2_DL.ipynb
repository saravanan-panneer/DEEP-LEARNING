# %% [markdown]
# Saravanan P
# 24BAD105
# EXP 2

# %% [markdown]
# TASK A: VISUALIZATION OF ACTIVATION FUNCTIONS

# %%
# Student Roll Nos: 24BAD105

import numpy as np
import matplotlib.pyplot as plt

# Input values
x = np.linspace(-10, 10, 400)

# Activation functions
sigmoid = 1 / (1 + np.exp(-x))
tanh = np.tanh(x)
relu = np.maximum(0, x)

# Plot
plt.figure(figsize=(12, 8))

plt.subplot(3, 1, 1)
plt.plot(x, sigmoid)
plt.title("Sigmoid Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()

plt.subplot(3, 1, 2)
plt.plot(x, tanh)
plt.title("Tanh Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()

plt.subplot(3, 1, 3)
plt.plot(x, relu)
plt.title("ReLU Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# TASK B: PERFORMANCE COMPARISON OF ACTIVATION FUNCTIONS

# %%
# Student Roll Nos: 24BAD105

import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocessing
x_train = x_train.reshape(-1, 784).astype("float32") / 255.0
x_test = x_test.reshape(-1, 784).astype("float32") / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Function to create ANN
def create_model(activation):
    model = Sequential([
        Dense(128, activation=activation, input_shape=(784,)),
        Dense(64, activation=activation),
        Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

activations = ["sigmoid", "tanh", "relu"]
histories = {}

for activation in activations:
    print("\nTraining with:", activation)

    model = create_model(activation)

    history = model.fit(
        x_train,
        y_train,
        validation_split=0.2,
        epochs=10,
        batch_size=128,
        verbose=1
    )

    histories[activation] = history

    loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

    print("Test Accuracy:", accuracy)

# Plot validation accuracy
plt.figure(figsize=(10, 6))

for activation, history in histories.items():
    plt.plot(
        history.history["val_accuracy"],
        label=activation
    )

plt.title("Validation Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid()
plt.show()
# Out:
# Training with: sigmoid
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7918 - loss: 0.8989 - val_accuracy: 0.9073 - val_loss: 0.3619
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9153 - loss: 0.3103 - val_accuracy: 0.9293 - val_loss: 0.2502
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9338 - loss: 0.2309 - val_accuracy: 0.9432 - val_loss: 0.2009
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9466 - loss: 0.1865 - val_accuracy: 0.9515 - val_loss: 0.1709
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9540 - loss: 0.1556 - val_accuracy: 0.9561 - val_loss: 0.1521
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9616 - loss: 0.1319 - val_accuracy: 0.9617 - val_loss: 0.1351
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9678 - loss: 0.1136 - val_accuracy: 0.9642 - val_loss: 0.1227
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9723 - loss: 0.0979 - val_accuracy: 0.9650 - val_loss: 0.1169
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9764 - loss: 0.0847 - val_accuracy: 0.9674 - val_loss: 0.1098
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9789 - loss: 0.0744 - val_accuracy: 0.9704 - val_loss: 0.1014
# Test Accuracy: 0.9710999727249146
#
# Training with: tanh
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8917 - loss: 0.3831 - val_accuracy: 0.9392 - val_loss: 0.2167
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9456 - loss: 0.1853 - val_accuracy: 0.9538 - val_loss: 0.1579
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9599 - loss: 0.1343 - val_accuracy: 0.9608 - val_loss: 0.1385
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9707 - loss: 0.1016 - val_accuracy: 0.9657 - val_loss: 0.1159
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9775 - loss: 0.0802 - val_accuracy: 0.9657 - val_loss: 0.1097
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9812 - loss: 0.0640 - val_accuracy: 0.9687 - val_loss: 0.1037
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9862 - loss: 0.0499 - val_accuracy: 0.9697 - val_loss: 0.1028
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9890 - loss: 0.0404 - val_accuracy: 0.9725 - val_loss: 0.0905
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9916 - loss: 0.0321 - val_accuracy: 0.9707 - val_loss: 0.0943
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9936 - loss: 0.0251 - val_accuracy: 0.9728 - val_loss: 0.0958
# Test Accuracy: 0.973800003528595
#
# Training with: relu
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8918 - loss: 0.3801 - val_accuracy: 0.9503 - val_loss: 0.1834
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9552 - loss: 0.1527 - val_accuracy: 0.9614 - val_loss: 0.1374
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9696 - loss: 0.1039 - val_accuracy: 0.9691 - val_loss: 0.1096
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9765 - loss: 0.0781 - val_accuracy: 0.9711 - val_loss: 0.0981
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9827 - loss: 0.0606 - val_accuracy: 0.9707 - val_loss: 0.0953
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9856 - loss: 0.0497 - val_accuracy: 0.9726 - val_loss: 0.0936
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9877 - loss: 0.0406 - val_accuracy: 0.9737 - val_loss: 0.0902
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9907 - loss: 0.0318 - val_accuracy: 0.9740 - val_loss: 0.0899
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9916 - loss: 0.0282 - val_accuracy: 0.9730 - val_loss: 0.0965
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9926 - loss: 0.0236 - val_accuracy: 0.9780 - val_loss: 0.0864
# Test Accuracy: 0.9768000245094299

# %% [markdown]
# TASK C: COMPARISON OF OPTIMIZATION ALGORITHMS

# %%
# Student Roll Nos: 24BAD105

import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocessing
x_train = x_train.reshape(-1, 784).astype("float32") / 255.0
x_test = x_test.reshape(-1, 784).astype("float32") / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Optimizers
optimizers = {
    "SGD": tf.keras.optimizers.SGD(learning_rate=0.01),
    "Momentum": tf.keras.optimizers.SGD(
        learning_rate=0.01,
        momentum=0.9
    ),
    "RMSProp": tf.keras.optimizers.RMSprop(
        learning_rate=0.001
    ),
    "Adam": tf.keras.optimizers.Adam(
        learning_rate=0.001
    )
}

histories = {}

for name, optimizer in optimizers.items():

    print("\nTraining with:", name)

    model = Sequential([
        Dense(128, activation="relu", input_shape=(784,)),
        Dense(64, activation="relu"),
        Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer=optimizer,
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    history = model.fit(
        x_train,
        y_train,
        validation_split=0.2,
        epochs=10,
        batch_size=128,
        verbose=1
    )

    histories[name] = history

# Loss comparison
plt.figure(figsize=(10, 6))

for name, history in histories.items():
    plt.plot(
        history.history["val_loss"],
        label=name
    )

plt.title("Validation Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid()
plt.show()

# Accuracy comparison
plt.figure(figsize=(10, 6))

for name, history in histories.items():
    plt.plot(
        history.history["val_accuracy"],
        label=name
    )

plt.title("Validation Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid()
plt.show()

# Final results
for name, history in histories.items():

    final_train_acc = history.history["accuracy"][-1]
    final_val_acc = history.history["val_accuracy"][-1]

    final_train_loss = history.history["loss"][-1]
    final_val_loss = history.history["val_loss"][-1]

    print("\n", name)
    print("Training Accuracy:", final_train_acc)
    print("Validation Accuracy:", final_val_acc)
    print("Training Loss:", final_train_loss)
    print("Validation Loss:", final_val_loss)
# Out:
# Training with: SGD
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6432 - loss: 1.3545 - val_accuracy: 0.8423 - val_loss: 0.6552
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8579 - loss: 0.5469 - val_accuracy: 0.8839 - val_loss: 0.4254
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8867 - loss: 0.4153 - val_accuracy: 0.9008 - val_loss: 0.3570
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8994 - loss: 0.3620 - val_accuracy: 0.9096 - val_loss: 0.3212
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9071 - loss: 0.3299 - val_accuracy: 0.9168 - val_loss: 0.2996
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9133 - loss: 0.3078 - val_accuracy: 0.9216 - val_loss: 0.2801
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9179 - loss: 0.2905 - val_accuracy: 0.9243 - val_loss: 0.2675
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9217 - loss: 0.2763 - val_accuracy: 0.9283 - val_loss: 0.2573
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9249 - loss: 0.2638 - val_accuracy: 0.9314 - val_loss: 0.2445
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9288 - loss: 0.2529 - val_accuracy: 0.9320 - val_loss: 0.2374
#
# Training with: Momentum
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8401 - loss: 0.5508 - val_accuracy: 0.9239 - val_loss: 0.2739
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9276 - loss: 0.2450 - val_accuracy: 0.9407 - val_loss: 0.2036
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9468 - loss: 0.1864 - val_accuracy: 0.9543 - val_loss: 0.1600
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9558 - loss: 0.1504 - val_accuracy: 0.9603 - val_loss: 0.1385
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9635 - loss: 0.1250 - val_accuracy: 0.9622 - val_loss: 0.1344
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9687 - loss: 0.1085 - val_accuracy: 0.9624 - val_loss: 0.1279
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9730 - loss: 0.0942 - val_accuracy: 0.9684 - val_loss: 0.1097
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9757 - loss: 0.0838 - val_accuracy: 0.9677 - val_loss: 0.1081
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9791 - loss: 0.0737 - val_accuracy: 0.9706 - val_loss: 0.1025
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9818 - loss: 0.0648 - val_accuracy: 0.9698 - val_loss: 0.1007
#
# Training with: RMSProp
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9023 - loss: 0.3472 - val_accuracy: 0.9462 - val_loss: 0.1847
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9554 - loss: 0.1515 - val_accuracy: 0.9563 - val_loss: 0.1479
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9687 - loss: 0.1050 - val_accuracy: 0.9636 - val_loss: 0.1199
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9758 - loss: 0.0801 - val_accuracy: 0.9703 - val_loss: 0.1002
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9810 - loss: 0.0637 - val_accuracy: 0.9723 - val_loss: 0.0975
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9848 - loss: 0.0513 - val_accuracy: 0.9747 - val_loss: 0.0982
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9865 - loss: 0.0426 - val_accuracy: 0.9754 - val_loss: 0.0894
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9893 - loss: 0.0353 - val_accuracy: 0.9762 - val_loss: 0.0887
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9911 - loss: 0.0296 - val_accuracy: 0.9737 - val_loss: 0.1067
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9926 - loss: 0.0238 - val_accuracy: 0.9759 - val_loss: 0.1012
#
# Training with: Adam
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8976 - loss: 0.3662 - val_accuracy: 0.9527 - val_loss: 0.1760
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9569 - loss: 0.1498 - val_accuracy: 0.9618 - val_loss: 0.1323
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9683 - loss: 0.1062 - val_accuracy: 0.9666 - val_loss: 0.1129
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9762 - loss: 0.0794 - val_accuracy: 0.9680 - val_loss: 0.1092
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9814 - loss: 0.0614 - val_accuracy: 0.9723 - val_loss: 0.0977
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9846 - loss: 0.0496 - val_accuracy: 0.9725 - val_loss: 0.0939
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9881 - loss: 0.0399 - val_accuracy: 0.9737 - val_loss: 0.0893
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9900 - loss: 0.0326 - val_accuracy: 0.9753 - val_loss: 0.0865
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9925 - loss: 0.0260 - val_accuracy: 0.9755 - val_loss: 0.0924
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9936 - loss: 0.0215 - val_accuracy: 0.9739 - val_loss: 0.0925
#  SGD
# Training Accuracy: 0.9287916421890259
# Validation Accuracy: 0.9319999814033508
# Training Loss: 0.2529185712337494
# Validation Loss: 0.2374008744955063
#
#  Momentum
# Training Accuracy: 0.9817500114440918
# Validation Accuracy: 0.9698333144187927
# Training Loss: 0.06478580087423325
# Validation Loss: 0.10068278759717941
#
#  RMSProp
# Training Accuracy: 0.9926041960716248
# Validation Accuracy: 0.9759166836738586
# Training Loss: 0.02383984811604023
# Validation Loss: 0.10124750435352325
#
#  Adam
# Training Accuracy: 0.9936458468437195
# Validation Accuracy: 0.9739166498184204
# Training Loss: 0.021525440737605095
# Validation Loss: 0.09246235340833664

# %% [markdown]
# TASK D: DEEP LEARNING EXPERIMENT MANAGEMENT

# %%
# Student Roll Nos: 24BAD105, 24BAD126

from google.colab import drive

drive.mount('/content/drive')


import os

folder = "/content/drive/MyDrive/DL_Experiments"

os.makedirs(folder, exist_ok=True)

print("Experiment folder created:", folder)

import os

folder = "/content/drive/MyDrive/DL_Experiments"

os.makedirs(folder, exist_ok=True)

print("Experiment folder created:", folder)

model.save(
    "/content/drive/MyDrive/DL_Experiments/ann_model.keras"
)

print("Model saved successfully.")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_807/1949176167.py in <cell line: 0>()
#       3 from google.colab import drive
#       4
# ----> 5 drive.mount('/content/drive')
#       6
#       7
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.13/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.13/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
